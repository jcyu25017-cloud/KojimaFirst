# %%
1+1
# Out:
# 2

# %%
3*5
# Out:
# 15

# %%
print('Hello World')
# Out:
# Hello World

# %%
print('dark')
# Out:
# dark

# %%
print('fff')
print('')
print('trem')
# Out:
# fff
#
# trem

# %%
s1 = 'aiueo'

# %%
s2 = ';;'
s3 = 55
s4 = 'aaa'
print(s1, s2, s3)
# Out:
# aiueo ;; 55

# %%
#in

# %%
...
print('ww')
...
# Out:
# ww
# Ellipsis

# %%
list1 = [10]
list1.append(40)
print(list1)
# Out:
# [10, 40]

# %%
for i in range(5):
    print('*')

a = 7

if(a >= 8):
    print('a')
elif(a < 6):
    print('b')
else:
    print('c')

while(a < 10):
    print(a)

    a = a + 1
# Out:
# *
# *
# *
# *
# *
# c
# 7
# 8
# 9

# %%
def summary(a, b):
    c = a + b
    return c

summary(3, 5)
# Out:
# 8

# %%
s1 = 'spr'
s2 = 'ing'
s3 = s1 + s2
print(s3)
# Out:
# spring

# %%
import numpy as np

a1 = np.array([1,2,3])

a2 = a1.tolist()

a3 = np.array(a2)

print(type(a1),a1)
# Out:
# <class 'numpy.ndarray'> [1 2 3]
